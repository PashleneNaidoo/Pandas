# %% [markdown]
# # Introduction to Pandas
#
# ### Pandas is an open-source library used for Data Analysis in Python.
#     - Built on the Numpy Library
#     Pandas Documentation : https://pandas.pydata.org/docs/
#     Github : https://github.com/PashleneNaidoo/Pandas/blob/main/Introduction_to_Pandas_Micro_School.ipynb

# %%
pip install pandas

# %% [markdown]
# ## Import Pandas
#   - We refer to pandas a pd everytime we use its functions.

# %%
import pandas as pd
print(pd.__version__)
import numpy as np
# Out:
# 2.0.3

# %% [markdown]
# # Series
#   - A Series is a one-dimensional array. Also known as a column.

# %%
# We create a list, in this instance we create a list of cars.
cars = ['Ferarri','Mercedes','Royals Royce','Porsche']

# We then feed the 'cars' list into the pd.Series() function to create a series 'mycars'
mycars = pd.Series(cars)

# Run the series
mycars
# Out:
# 0         Ferarri
# 1        Mercedes
# 2    Royals Royce
# 3         Porsche
# dtype: object

# %%
# We create another list describing the number of cars of each kind.
quantity_of_cars = [2,10,6,1]

# Feed the list into the pd.Series() function to create a series 'myquantity_cars'
myquantity_cars = pd.Series(quantity_of_cars)

# Run the series
myquantity_cars
# Out:
# 0     2
# 1    10
# 2     6
# 3     1
# dtype: int64

# %% [markdown]
# # DataFrame
#   - A dataframe is 2 dimensional array. We can think of table with columns and rows.

# %%
# We can combine two series to create a DataFrame.
# We use the pd.DataFrame() function and feed the two series with their column names
# Seperated by a "," comma . To create a Dataframe 'garage_home'.

garage_home = pd.DataFrame({
    'Car Brand': mycars,
    'Number of Cars': myquantity_cars
})

# Run the DataFrame
garage_home
# Out:
#       Car Brand  Number of Cars
# 0       Ferarri               2
# 1      Mercedes              10
# 2  Royals Royce               6
# 3       Porsche               1

# %%
 # A Dataframe can be create using a list of tuples.
 garage_cpt = [('Lamboghini',1),('Mustang',4),('BMW',1),('Porsche',3)]

 #The list is fed into the dataframe function and
 # the columns are defined respectively to the tuple.
 mygarage_cpt = pd.DataFrame(garage_cpt,columns=['Car Brand','Number of Cars'])

 # Run the dataframe
 mygarage_cpt
# Out:
#     Car Brand  Number of Cars
# 0  Lamboghini               1
# 1     Mustang               4
# 2         BMW               1
# 3     Porsche               3

# %%
# Create a three column dataframe with three inputs in each tuple.
garage_monaco = [('Ferarri',1,'red'),('Mercedes',4,'white'),('Lamboghini',1,'purple'),('Royals Royce',1,'black'),('Porsche',3,'blue')]

#The list is fed into the dataframe function and
# the columns are defined respectively to the tuple.
mygarage_monaco = pd.DataFrame(garage_monaco,columns=['Car Brand','Number of Cars','Color of Car'])

# Run the dataframe
mygarage_monaco
# Out:
#       Car Brand  Number of Cars Color of Car
# 0       Ferarri               1          red
# 1      Mercedes               4        white
# 2    Lamboghini               1       purple
# 3  Royals Royce               1        black
# 4       Porsche               3         blue

# %% [markdown]
# ### Access a row

# %%
# To access the first row of the dataframe the .loc[] is used
# and is fed '0' describing the first row
mygarage_cpt.loc[0]
# Out:
# Car Brand         Lamboghini
# Number of Cars             1
# Name: 0, dtype: object

# %% [markdown]
# ### Access a column

# %%
# To access the a column a pair a sqaure brackets is used grab the desired column
mygarage_cpt['Car Brand']
# Out:
# 0    Lamboghini
# 1       Mustang
# 2           BMW
# 3       Porsche
# Name: Car Brand, dtype: object

# %% [markdown]
# ### Access an element in a Column

# %%
# To access an element in a column we first define the column
# and then define the row index --> dataframe_name[column][row]
mygarage_cpt['Car Brand'][0]
# Out:
# 'Lamboghini'

# %% [markdown]
# ### Replacing elements in columns

# %%
# We can assign a new value to the element

mygarage_cpt['Car Brand'][0] = 'Tesla'

# Run the DataFrame
mygarage_cpt
# Out:
# <ipython-input-45-7aa17b4fb484>:3: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment.
# When using the Copy-on-Write mode, such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mygarage_cpt['Car Brand'][0] = 'Tesla'
#     Car Brand  Number of Cars
# 0  Lamboghini               1
# 1     Mustang               4
# 2         BMW               1
# 3     Porsche               3

# %%
# Assigning the first row  of the 'Number of Cars' column  to a new value
mygarage_cpt['Number of Cars'][0] = mygarage_cpt['Number of Cars'][0]*5

# Run the DataFrame
mygarage_cpt
# Out:
# <ipython-input-12-8c7296fc819d>:2: ChainedAssignmentError: A value is trying to be set on a copy of a DataFrame or Series through chained assignment.
# When using the Copy-on-Write mode, such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy.
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mygarage_cpt['Number of Cars'][0] = mygarage_cpt['Number of Cars'][0]*5
#     Car Brand  Number of Cars
# 0  Lamboghini               1
# 1     Mustang               4
# 2         BMW               1
# 3     Porsche               3

# %% [markdown]
# ### The type of data in dataframes

# %%
# Use .dtypes to describe the data types in the dataframe
mygarage_cpt.dtypes
# Out:
# Car Brand         object
# Number of Cars     int64
# dtype: object

# %% [markdown]
# ### Removal of index

# %%
# To remove the index in a dataframe we replace the index with a clolumn
# that has unique values
new_df = mygarage_cpt.set_index('Car Brand')

# Run the DataFrame
new_df
# Out:
#             Number of Cars
# Car Brand
# Lamboghini               1
# Mustang                  4
# BMW                      1
# Porsche                  3

# %% [markdown]
# # Save Data

# %%
# To save your Data. Use the to_csv() function
# and feed the function a file name where it will save the data
new_df.to_csv('CarData.csv')

# The data will be saved under 'Files' in GoogleColab.

# %% [markdown]
# # Plotting the Data

# %%
# We can create plots using matplotlib.
import matplotlib.pyplot as plt

# Pie chart
plt.pie(mygarage_cpt['Number of Cars'], labels=mygarage_cpt['Car Brand'], autopct="%1.1f%%")
plt.title("Car Brand Distribution (Pie Chart)")
plt.show()

# We can use the columns in the dataframe as our x and y axis data.
# We use the Car brand and Number of Cars columns
# from the mygarage_cpt dataframe

# Bar chart with color
plt.bar(mygarage_cpt['Car Brand'], mygarage_cpt['Number of Cars'], color='skyblue')
plt.xlabel('Car Brand')
plt.ylabel('Number of Cars')
plt.title('Car Brand Distribution (Bar Chart)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# Line graph
plt.plot(mygarage_cpt['Car Brand'], mygarage_cpt['Number of Cars'])
plt.xlabel('Car Brand')
plt.ylabel('Number of Cars')
plt.title('Car Brand Distribution (Line Graph)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# Scatter plot
plt.scatter(mygarage_cpt['Car Brand'], mygarage_cpt['Number of Cars'])
plt.xlabel('Car Brand')
plt.ylabel('Number of Cars')
plt.title('Car Brand Distribution (Scatter Plot)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# # Reading in Data

# %%
# A dataframe can be created by reading a csv or excel file using the read.csv() function
# Drag and drop the csv file to 'Files' then copy and paste the path in the function.
# define the type of encoding the file has so that pandas can read it correctly.
df = pd.read_csv('/content/Most Streamed Spotify Songs 2024.csv', encoding='latin-1') # Reading the file with 'latin-1' encoding

# Use the head() function to view the first few rows of the dataset
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
# Use the tail() function to view the last few rows of the dataset
df.tail(2)
# Out:
#                                 Track                       Album Name  \
# 4598              Nashe Si Chadh Gayi            November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)  Me Acostumbre (feat. Bad Bunny)
#
#             Artist Release Date          ISRC All Time Rank  Track Score  \
# 4598  Arijit Singh    11/8/2016  INY091600067         4,591         19.4
# 4599     Arcï¿½ï¿½    4/11/2017  USB271700107         4,593         19.4
#
#      Spotify Streams Spotify Playlist Count Spotify Playlist Reach  ...  \
# 4598     145,467,020                 14,037              7,387,064  ...
# 4599     255,740,653                 32,138             14,066,526  ...
#
#       SiriusXM Spins Deezer Playlist Count Deezer Playlist Reach  \
# 4598             NaN                   NaN                   NaN
# 4599             NaN                   4.0               127,479
#
#      Amazon Playlist Count Pandora Streams Pandora Track Stations  \
# ...

# %%
# View the Artist Column
df['Artist']
# Out:
# 0        Tommy Richman
# 1       Kendrick Lamar
# 2              Artemas
# 3          Miley Cyrus
# 4               Eminem
#              ...
# 4595       $uicideboy$
# 4596        Atif Aslam
# 4597          Lil Baby
# 4598      Arijit Singh
# 4599         Arcï¿½ï¿½
# Name: Artist, Length: 4600, dtype: object

# %%
# View row 3 of the dataset
df.loc[3]
# Out:
# Track                                  Flowers
# Album Name                    Flowers - Single
# Artist                             Miley Cyrus
# Release Date                         1/12/2023
# ISRC                              USSM12209777
# All Time Rank                                4
# Track Score                              444.9
# Spotify Streams                  2,031,280,633
# Spotify Playlist Count                 269,802
# Spotify Playlist Reach             136,569,078
# Spotify Popularity                        85.0
# YouTube Views                    1,096,100,899
# YouTube Likes                       10,629,796
# TikTok Posts                         7,189,811
# TikTok Likes                     1,078,757,968
# TikTok Views                    14,603,725,994
# YouTube Playlist Reach           3,351,188,582
# Apple Music Playlist Count               394.0
# AirPlay Spins                        1,474,799
# SiriusXM Spins                           2,182
# ...

# %%
# Lets view the data type of each column to understand our data better.
df.dtypes
# Out:
# Track                          object
# Album Name                     object
# Artist                         object
# Release Date                   object
# ISRC                           object
# All Time Rank                  object
# Track Score                   float64
# Spotify Streams                object
# Spotify Playlist Count         object
# Spotify Playlist Reach         object
# Spotify Popularity            float64
# YouTube Views                  object
# YouTube Likes                  object
# TikTok Posts                   object
# TikTok Likes                   object
# TikTok Views                   object
# YouTube Playlist Reach         object
# Apple Music Playlist Count    float64
# AirPlay Spins                  object
# SiriusXM Spins                 object
# Deezer Playlist Count         float64
# Deezer Playlist Reach          object
# Amazon Playlist Count         float64
# Pandora Streams                object
# Pandora Track Stations         object
# ...

# %% [markdown]
# # Cleaning Data

# %%
# Let begin cleaning our Data.
mydf = df.set_index('ISRC')

# %%
# The indices have been replaced by 'ISRC'
mydf.head()
# Out:
#                                    Track                    Album Name  \
# ISRC
# QM24S2402528         MILLION DOLLAR BABY  Million Dollar Baby - Single
# USUG12400910                 Not Like Us                   Not Like Us
# QZJ842400387  i like the way you kiss me    I like the way you kiss me
# USSM12209777                     Flowers              Flowers - Single
# USUG12403398                     Houdini                       Houdini
#
#                       Artist Release Date All Time Rank  Track Score  \
# ISRC
# QM24S2402528   Tommy Richman    4/26/2024             1        725.4
# USUG12400910  Kendrick Lamar     5/4/2024             2        545.9
# QZJ842400387         Artemas    3/19/2024             3        538.4
# USSM12209777     Miley Cyrus    1/12/2023             4        444.9
# USUG12403398          Eminem    5/31/2024             5        423.3
#
#              Spotify Streams Spotify Playlist Count Spotify Playlist Reach  \
# ISRC
# ...

# %%
# To locate a specific song we need to its unique ISRC code.
mydf.loc['USSM12209777'] # previously at index 3
# Out:
# Track                                  Flowers
# Album Name                    Flowers - Single
# Artist                             Miley Cyrus
# Release Date                         1/12/2023
# All Time Rank                                4
# Track Score                              444.9
# Spotify Streams                  2,031,280,633
# Spotify Playlist Count                 269,802
# Spotify Playlist Reach             136,569,078
# Spotify Popularity                        85.0
# YouTube Views                    1,096,100,899
# YouTube Likes                       10,629,796
# TikTok Posts                         7,189,811
# TikTok Likes                     1,078,757,968
# TikTok Views                    14,603,725,994
# YouTube Playlist Reach           3,351,188,582
# Apple Music Playlist Count               394.0
# AirPlay Spins                        1,474,799
# SiriusXM Spins                           2,182
# Deezer Playlist Count                    264.0
# ...

# %%
# Describes the shape of our data
mydf.shape
# Out:
# (4600, 28)

# %%
# Lets create a dataframe with data that we want to work with.
my_songs = mydf[['Track', 'Artist', 'Release Date',
         'All Time Rank', 'Spotify Streams', 'YouTube Views',
         'YouTube Likes','TikTok Views','TikTok Likes']]

# Run the dataframe
my_songs
# Out:
#                                         Track          Artist Release Date  \
# ISRC
# QM24S2402528              MILLION DOLLAR BABY   Tommy Richman    4/26/2024
# USUG12400910                      Not Like Us  Kendrick Lamar     5/4/2024
# QZJ842400387       i like the way you kiss me         Artemas    3/19/2024
# USSM12209777                          Flowers     Miley Cyrus    1/12/2023
# USUG12403398                          Houdini          Eminem    5/31/2024
# ...                                       ...             ...          ...
# QM8DG1703420                For the Last Time     $uicideboy$     9/5/2017
# INT101800122                 Dil Meri Na Sune      Atif Aslam    7/27/2018
# USUG12000043            Grace (feat. 42 Dugg)        Lil Baby    2/28/2020
# INY091600067              Nashe Si Chadh Gayi    Arijit Singh    11/8/2016
# USB271700107  Me Acostumbre (feat. Bad Bunny)       Arcï¿½ï¿½    4/11/2017
#
# ...

# %%
# Describes the data types in the my_songs dataframe.
my_songs.dtypes
# Out:
# Track              object
# Artist             object
# Release Date       object
# All Time Rank      object
# Spotify Streams    object
# YouTube Views      object
# YouTube Likes      object
# TikTok Views       object
# TikTok Likes       object
# dtype: object

# %% [markdown]
# # Changing DataTypes

# %%
# Lets change the 'All Time Rank' column to integer type.
#my_songs['All Time Rank']

#step 1 : Look at data and identify what it contains. It has a bunch of commas.
# It should contain a point or just a number.
#my_songs['All Time Rank'].astype(str).str.replace(',', '')

#step2 : The data contains only numbers. We change the data type to an integer.
#my_songs['All Time Rank'] = my_songs['All Time Rank'].astype(str).str.replace(',', '').astype('int')

# %%
# Convert 'All Time Rank' column to string type before using .str accessor
pd.options.mode.copy_on_write = True
mydf['All Time Rank'] = mydf['All Time Rank'].astype(str).str.replace(',', '').astype('int') # Remove commas before converting to integer

# %%
# Convert 'Spotify Streams' column to string type, remove commas, and then convert to integer
my_songs['Spotify Streams'] = my_songs['Spotify Streams'].fillna('0').astype(str).str.replace(',', '').astype('int') # Explicitly convert to string type after filling NaN

# %%
# Convert 'YouTube Views' column to string type, remove commas, fill NaN with '0', and then convert to integer
my_songs['YouTube Views'] = my_songs['YouTube Views'].str.replace(',', '').fillna('0').astype('int') # Fill NaN with '0' before conversion

# %%
# Convert 'YouTube Likes' column to string type, remove commas, fill NaN with '0', and then convert to integer
my_songs['YouTube Likes'] = my_songs['YouTube Likes'].str.replace(',', '').fillna('0').astype(int) # Clean and convert

# %%
#TikTok Views
my_songs['TikTok Views'] = my_songs['TikTok Views'].str.replace(',', '').fillna('0').astype(int) # Clean and convert

# %%
#TikTok Likes
my_songs['TikTok Likes'] = my_songs['TikTok Likes'].str.replace(',', '').fillna('0').astype(int) # Clean and convert

# %%
my_songs['Release Date'] = pd.to_datetime(my_songs['Release Date']) # Convert 'Release Date' column to datetime

# %%
# The my_songs dataframe contains the correct data types.
my_songs.dtypes
# Out:
# Track                      object
# Artist                     object
# Release Date       datetime64[ns]
# All Time Rank              object
# Spotify Streams             int64
# YouTube Views               int64
# YouTube Likes               int64
# TikTok Views                int64
# TikTok Likes                int64
# dtype: object

# %%
# Cleaned Data
my_songs.head()
# Out:
#                                    Track          Artist Release Date  \
# ISRC
# QM24S2402528         MILLION DOLLAR BABY   Tommy Richman   2024-04-26
# USUG12400910                 Not Like Us  Kendrick Lamar   2024-05-04
# QZJ842400387  i like the way you kiss me         Artemas   2024-03-19
# USSM12209777                     Flowers     Miley Cyrus   2023-01-12
# USUG12403398                     Houdini          Eminem   2024-05-31
#
#              All Time Rank  Spotify Streams  YouTube Views  YouTube Likes  \
# ISRC
# QM24S2402528             1        390470936       84274754        1713126
# USUG12400910             2        323703884      116347040        3486739
# QZJ842400387             3        601309283      122599116        2228730
# USSM12209777             4       2031280633     1096100899       10629796
# USUG12403398             5        107034922       77373957        3670188
#
#               TikTok Views  TikTok Likes
# ISRC
# ...

# %% [markdown]
# # Using the Cleaned Data

# %%
# Lets use our cleaned data.
# Lets find the top 10 songs currently in 2024.
# The .loc[] function locates the data in the 'All Time Rank' column that is less than 11.
my_TopTen_songs = my_songs.loc[mydf['All Time Rank'] < 11]

# Run the dataframe
# Top ten songs in 2024 currently on spotify.
my_TopTen_songs
# Out:
#                                    Track          Artist Release Date  \
# ISRC
# QM24S2402528         MILLION DOLLAR BABY   Tommy Richman   2024-04-26
# USUG12400910                 Not Like Us  Kendrick Lamar   2024-05-04
# QZJ842400387  i like the way you kiss me         Artemas   2024-03-19
# USSM12209777                     Flowers     Miley Cyrus   2023-01-12
# USUG12403398                     Houdini          Eminem   2024-05-31
# USAT22311371                 Lovin On Me     Jack Harlow   2023-11-10
# USWB12307016            Beautiful Things    Benson Boone   2024-01-18
# QZL382406049                   Gata Only      FloyyMenor   2024-02-02
# TCJPA2463708        Danza Kuduro - Cover   MUSIC LAB JPN   2024-06-09
# USSM12404354  BAND4BAND (feat. Lil Baby)     Central Cee   2024-05-23
#
#              All Time Rank  Spotify Streams  YouTube Views  YouTube Likes  \
# ISRC
# QM24S2402528             1        390470936       84274754        1713126
# ...

# %% [markdown]
# # Creating a new column

# %%
# A new column can be created using existing columns.
# We create a 'Total Views' column by adding the youtube views and tiktko view columns.
my_songs['Total Views'] = my_songs['YouTube Views'] + my_songs['TikTok Views']

# Run the dataframe
my_songs.head()
# Out:
#                                    Track          Artist Release Date  \
# ISRC
# QM24S2402528         MILLION DOLLAR BABY   Tommy Richman   2024-04-26
# USUG12400910                 Not Like Us  Kendrick Lamar   2024-05-04
# QZJ842400387  i like the way you kiss me         Artemas   2024-03-19
# USSM12209777                     Flowers     Miley Cyrus   2023-01-12
# USUG12403398                     Houdini          Eminem   2024-05-31
#
#              All Time Rank  Spotify Streams  YouTube Views  YouTube Likes  \
# ISRC
# QM24S2402528             1        390470936       84274754        1713126
# USUG12400910             2        323703884      116347040        3486739
# QZJ842400387             3        601309283      122599116        2228730
# USSM12209777             4       2031280633     1096100899       10629796
# USUG12403398             5        107034922       77373957        3670188
#
#               TikTok Views  TikTok Likes  Total Views
# ISRC
# ...

# %%
# Describe some statistics in our dataframe
my_songs.describe()
# Out:
#                         Release Date  Spotify Streams  YouTube Views  \
# count                           4600     4.600000e+03   4.600000e+03
# mean   2021-01-27 07:48:18.782608896     4.363971e+08   3.758269e+08
# min              1987-07-21 00:00:00     0.000000e+00   0.000000e+00
# 25%              2019-07-16 18:00:00     6.340627e+07   2.821574e+07
# 50%              2022-06-01 00:00:00     2.263761e+08   1.283531e+08
# 75%              2023-08-11 00:00:00     6.113563e+08   4.204637e+08
# max              2024-06-14 00:00:00     4.281469e+09   1.632276e+10
# std                              NaN     5.362792e+08   6.854251e+08
#
#        YouTube Likes  TikTok Views  TikTok Likes   Total Views
# count   4.600000e+03  4.600000e+03  4.600000e+03  4.600000e+03
# mean    2.729404e+06  9.135283e+08  8.864079e+07  1.289355e+09
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     2.887055e+05  8.629830e+05  7.315525e+04  8.937091e+07
# ...

# %% [markdown]
# # Plot Examples

# %%
# We can plot the relationship between spotify streams and youtube views.
plt.figure(figsize=(10, 6))
plt.scatter(my_songs["Spotify Streams"], my_songs["YouTube Views"])
plt.xlabel("Spotify Streams")
plt.ylabel("YouTube Views")
plt.title("Spotify Streams vs. YouTube Views")
plt.show()

# %%
#mydf.plot(kind='scatter', x='YouTube Views', y='YouTube Likes', title='Youtube View vs  Youtube Like Count')

plt.figure(figsize=(10, 6))
plt.scatter(my_songs["YouTube Views"], my_songs["YouTube Likes"])
plt.xlabel("YouTube Views")
plt.ylabel("YouTube Likes")
plt.title("YouTube Views vs. YouTube Likes")
plt.show()

# %%
# We can filter our data according to a specific condtion using the query() function.
# In this case we want songs that have more than 10 million like on youtube.
filtered_df = my_songs.query('`YouTube Likes` > 10000000')
filtered_df
# Out:
#                                         Track                 Artist  \
# ISRC
# USSM12209777                          Flowers            Miley Cyrus
# NLC242100307                   bathroom floor         Kids With Buns
# USSM12103949        STAY (with Justin Bieber)          The Kid LAROI
# KRE671700001                       Baby Shark               Pinkfong
# QZES71982312                     Dance Monkey            Tones And I
# ...                                       ...                    ...
# USRH11200639  Gangsta's Paradise (feat. L.V.)                 Coolio
# GBAYE0200772                    The Scientist               Coldplay
# USMAC0100119                 Over the Rainbow  Israel Kamakawiwo'ole
# QM6N22036182                        Daechwita                Agust D
# AUNV01400494                          Animals          Martin Garrix
#
#              Release Date All Time Rank  Spotify Streams  YouTube Views  \
# ISRC
# ...

# %% [markdown]
# # Save Cleaned Data

# %%
# We save out filtered data in the file name 'processed_data.csv'
filtered_df.to_csv('processed_data.csv')

# The data will be saved under 'Files' in GoogleColab.
